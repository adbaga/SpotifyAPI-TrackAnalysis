# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import os
import cred

# %%
#Create your spotify account and get your client id and client secret here
#https://developer.spotify.com/dashboard/applications
#create a file called cred.py in the same directory and include client_id and client_secret into the file:
            #client_id = 'yourClientID'
            #client_secret = 'YourClientSecret'



class PlayListDownloader:                
    client_id = cred.client_id
    client_secret = cred.client_secret
    client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    
    def __init__(self,outputName, user, playlistid: str):  
        self.outputName = outputName
        self.user = user
        self.playlist_id = playlistid
        id = ''
        self.ids = self.getTrackIDs()
        self.tracks = self.getTrackFeatures()
        self.df = self.createTrackList()
    
    def getTrackIDs(self):
        ids = []
        playlist = PlayListDownloader.sp.user_playlist(self.user, self.playlist_id)
        for item in playlist['tracks']['items']:
            track = item['track']
            ids.append(track['id'])
            PlayListDownloader.ids = ids
        return ids
        

    def getTrackFeatures(self):
        tracks = []
        ids = self.ids
        for id in ids:
            time.sleep(.5)
            meta = PlayListDownloader.sp.track(id)
            features = PlayListDownloader.sp.audio_features(id)
            
            # metadata
            #more information: https://developer.spotify.com/documentation/web-api/reference/tracks/get-track/
            name = meta['name']
            album = meta['album']['name']
            artist = meta['album']['artists'][0]['name']
            release_date = meta['album']['release_date']
            length = meta['duration_ms']
            popularity = meta['popularity']

            # features of the music
            #more information: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
            acousticness = features[0]['acousticness']
            danceability = features[0]['danceability']
            energy = features[0]['energy']
            instrumentalness = features[0]['instrumentalness']
            liveness = features[0]['liveness']
            loudness = features[0]['loudness']
            speechiness = features[0]['speechiness']
            tempo = features[0]['tempo']
            time_signature = features[0]['time_signature']
            valence = features[0]['valence']

            track = [name, album, artist, release_date, length, popularity,acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature,valence]
            tracks.append(track)
        
        return tracks
    
            

    def createTrackList(self):
        # create dataset
        df = pd.DataFrame(self.tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature','valence'])
        #Creating csv file from the dataFrame
        fileName = "spotify_{0}".format(self.outputName)
        df.to_csv("../data/"+fileName+".csv", sep = ',')
        return df
    
    def heatMap(self):
        self.corr = self.df[['popularity','acousticness','danceability','energy','instrumentalness','liveness','tempo','valence']].corr()
        mask = np.zeros_like(self.corr, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True
        sns.set(style='darkgrid')
        plt.figure(figsize=(12,8))
        ax = sns.heatmap(self.corr, annot=True, mask=mask)
        ax.collections[0].colorbar.set_label("Playlist heatmap")
        return ax
    
    @classmethod
    def changeCred(cls, client_id, client_secret):
        cls.client_id = client_id
        cls.client_secret = client_secret
        cls.client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
        cls.sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# <h2>Infortmation about the Playlist</h2>
# <ul>Playlist
#     <li> pl1 : Top 50 Global</li>
#  </ul>

# %%
#to make an instance, include these parameters: 'your outputfilename (It's recommended to use 
#the same name of your instance), spotify account username, playlist id'
pl1 = PlayListDownloader('PL1','adityaiqbal', '37i9dQZEVXbMDoHDwVN2tF')

# %%
pl1.heatMap()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-14eaccd60b8b> in <module>
# ----> 1 pl1.heatMap()
#
# <ipython-input-153-680f289add04> in heatMap(self)
#      79     def heatMap(self):
#      80         self.corr = self.df[['popularity','acousticness','danceability','energy','instrumentalness','liveness','tempo','valence']].corr()
# ---> 81         mask = np.zeros_like(corr, dtype=np.bool)
#      82         mask[np.triu_indices_from(mask)] = True
#      83         sns.set(style='darkgrid')
#
# NameError: name 'corr' is not defined

# %%
pl1.df.head()
# Out:
#                                name                             album  \
# 0  Savage Love (Laxed - Siren Beat)  Savage Love (Laxed - Siren Beat)
# 1      ROCKSTAR (feat. Roddy Ricch)                  BLAME IT ON BABY
# 2                   Blinding Lights                       After Hours
# 3                  Watermelon Sugar                         Fine Line
# 4                         my future                         my future
#
#           artist release_date  length  popularity  acousticness  danceability  \
# 0      Jawsh 685   2020-06-11  171374          96       0.23400         0.767
# 1         DaBaby   2020-04-17  181733         100       0.24700         0.746
# 2     The Weeknd   2020-03-20  200040          99       0.00146         0.514
# 3   Harry Styles   2019-12-13  174000          96       0.12200         0.548
# 4  Billie Eilish   2020-07-30  208155          83       0.79500         0.444
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.481          0.000000    0.2690    -8.520       0.0803  150.076
# 1   0.690          0.000000    0.1010    -7.956       0.1640   89.977
# 2   0.730          0.000095    0.0897    -5.934       0.0598  171.005
# 3   0.816          0.000000    0.3350    -4.209       0.0465   95.390
# 4   0.309          0.132000    0.3520   -10.956       0.0620  104.745
#
#    time_signature  valence
# 0               4   0.7610
# 1               4   0.4970
# 2               4   0.3340
# 3               4   0.5570
# 4               4   0.0875

# %% [markdown]
# <h4>Correlation heat map

# %%
pl1.corr = pl1.df[['popularity','acousticness','danceability','energy','instrumentalness','liveness','tempo','valence']].corr()

sns.set(style='darkgrid')
plt.figure(figsize=(12,8))
ax = sns.heatmap(pl1.corr, annot=True)
ax.collections[0].colorbar.set_label("Top 50 Global Playlist")

# %%
pl1.df[['artist','energy','acousticness','popularity']].groupby('artist').mean().sort_values(by='energy', ascending=False)[:10]
# Out:
#               energy  acousticness  popularity
# artist
# Joel Corry     0.874       0.16800        87.0
# Lady Gaga      0.855       0.02100        87.0
# Harry Styles   0.816       0.12200        96.0
# Ozuna          0.806       0.05310        92.0
# BLACKPINK      0.782       0.06940        89.0
# Surf Mesa      0.774       0.06860        94.0
# Dua Lipa       0.761       0.08965        88.5
# The Weeknd     0.730       0.00146        99.0
# SAINt JHN      0.724       0.01670        95.0
# Jack Harlow    0.723       0.06310        92.0

# %%
pl1.df.acousticness.mean()
# Out:
# 0.27154059999999997

# %%
pl2 = PlayListDownloader('PL2','adityaiqbal', '7g2KyiE9RI5F1fV60OIUu4')

# %%
pl2.df.head()
# Out:
#                       name                                              album  \
# 0        Of Dreams To Come                                      In My Element
# 1       Basin Street Blues                                            The Cat
# 2  Makin' Whoopee - Take 1               Louis Armstrong - Ambassador Of Jazz
# 3             Birks' Works             Verve Jazz Masters 10: Dizzy Gillespie
# 4          Time After Time  The Definitive John Coltrane On Prestige And R...
#
#             artist release_date  length  popularity  acousticness  \
# 0   Robert Glasper   2007-01-01  491466          29         0.892
# 1      Jimmy Smith   1998-01-01  239133           0         0.836
# 2  Louis Armstrong   2011-01-01  272533           0         0.775
# 3  Dizzy Gillespie         1994  297493           0         0.692
# 4    John Coltrane   2010-01-01  465106           0         0.947
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.436   0.432             0.822     0.119   -16.085       0.0543
# 1         0.452   0.445             0.806     0.175   -13.832       0.0378
# 2         0.591   0.196             0.000     0.541   -16.486       0.1120
# 3         0.506   0.443             0.710     0.234    -9.237       0.0606
# 4         0.555   0.237             0.602     0.145   -10.224       0.0388
#
#      tempo  time_signature  valence
# 0  111.638               3    0.133
# 1  140.496               1    0.714
# 2   73.489               4    0.416
# 3  133.845               4    0.626
# 4   91.553               4    0.338

# %%
pl2.corr = pl1.df[['popularity','acousticness','danceability','energy','instrumentalness','liveness','tempo','valence']].corr()

sns.set(style='darkgrid')
plt.figure(figsize=(12,8))
sns.heatmap(pl2.corr, annot=True)

# %% [markdown]
# <h2>Sad and Happy Music

# %%
pl3 = PlayListDownloader('PL2','adityaiqbal', '7ABD15iASBIpPP5uJ5awvq') #sad music

# %%
pl4 = PlayListDownloader('PL2','adityaiqbal', '37i9dQZF1DWUAZoWydCivZ') #positive vibes

# %%
for i in range(len(pl3.df)):
    pl3.df['sad'] = 1
for i in range(len(pl4.df)):
    pl4.df['sad'] = 0

# %%
pl3.df
# Out:
#                                        name  \
# 0                                The A Team
# 1                                Breathe Me
# 2                                   Falling
# 3                               Skinny Love
# 4                                     Youth
# ..                                      ...
# 95                             Conversation
# 96  The Good in Goodbye (Alternate Version)
# 97                       Such Great Heights
# 98                             Recording 15
# 99                        Better Than Today
#
#                                       album          artist release_date  \
# 0                                The A Team      Ed Sheeran   2011-05-01
# 1                      Colour The Small One             Sia   2004-01-01
# 2                                 Fine Line    Harry Styles   2019-12-13
# 3                     For Emma, Forever Ago        Bon Iver   2008-05-12
# 4                         The Wild Youth EP        Daughter   2012-02-29
# ..                                      ...             ...          ...
# 95                             Conversation       Lucy Rose   2019-01-10
# 96  The Good in Goodbye (Alternate Version)  Alexander Wren   2019-10-25
# 97                          Around The Well     Iron & Wine   2009-05-19
# 98                             Living Water     Shannon Lay   2017-09-22
# 99                        Better Than Today      Rhys Lewis   2019-01-04
#
#     length  popularity  acousticness  danceability  energy  instrumentalness  \
# 0   258588          34        0.6780         0.626   0.286          0.000000
# 1   272800          68        0.0364         0.552   0.643          0.740000
# 2   240133          86        0.8390         0.567   0.267          0.000001
# 3   238532          67        0.8420         0.592   0.256          0.000002
# 4   251626           0        0.6100         0.588   0.477          0.001880
# ..     ...         ...           ...           ...     ...               ...
# 95  229560          45        0.9010         0.242   0.137          0.010500
# 96  249576          40        0.5900         0.709   0.299          0.002920
# 97  251280           0        0.8080         0.610   0.275          0.913000
# 98  242000          60        0.9560         0.552   0.126          0.015300
# 99  230353          61        0.7360         0.387   0.234          0.000000
#
#     liveness  loudness  speechiness    tempo  time_signature  valence  sad
# 0      0.134    -9.933       0.0374   84.954               4   0.3660    1
# 1      0.105    -7.360       0.0327  120.012               4   0.2120    1
# 2      0.089    -6.502       0.0299  110.011               4   0.0592    1
# 3      0.088   -14.031       0.0449   76.361               4   0.1030    1
# 4      0.122   -12.710       0.0492  150.396               4   0.4880    1
# ..       ...       ...          ...      ...             ...      ...  ...
# 95     0.167   -16.332       0.0322   92.454               3   0.0644    1
# 96     0.111    -9.001       0.0297  112.984               3   0.4230    1
# 97     0.403   -10.644       0.0280   94.088               4   0.5520    1
# 98     0.109   -18.014       0.0306   92.441               4   0.4390    1
# 99     0.084    -8.861       0.0373   78.650               4   0.4080    1
#
# [100 rows x 17 columns]

# %%
pl4.df
# Out:
#                                                  name  \
# 0                                                Mama
# 1                                              Flames
# 2                            One Kiss (with Dua Lipa)
# 3                                             Clarity
# 4                                              Middle
# 5                                 Roses (feat. ROZES)
# 6                                           One Dance
# 7                                             Starboy
# 8                                   Cake By The Ocean
# 9                                            Fast Car
# 10                               Titanium (feat. Sia)
# 11                              How Deep Is Your Love
# 12                                          Happy Now
# 13                Dance To This (feat. Ariana Grande)
# 14                                             Closer
# 15                      Strip That Down (feat. Quavo)
# 16                                 Can't Feel My Face
# 17                                         Slow Hands
# 18                                            Problem
# 19                                            Classic
# 20                                        Love Myself
# 21                                         The Middle
# 22                                       Can We Dance
# 23                                           Who Says
# 24                                    Trust Fund Baby
# 25                           Worth It (feat. Kid Ink)
# 26             Pretty Girl - Cheat Codes X CADE Remix
# 27                                         Break Free
# 28                                               2002
# 29                                  Really Don't Care
# 30                              You Need To Calm Down
# 31                                          All Night
# 32                                     Hit The Lights
# 33                         Better - SG Lewis x Clairo
# 34                                               BO$$
# 35                                             Sucker
# 36                                            The Way
# 37                                  If You're Over Me
# 38                                    Sorry Not Sorry
# 39                   Lonely Together (feat. Rita Ora)
# 40                                On Top Of The World
# 41                                        I Found You
# 42                                      We Found Love
# 43                        Electricity (with Dua Lipa)
# 44                                           HandClap
# 45                 Don't You Worry Child - Radio Edit
# 46  Get Lucky (feat. Pharrell Williams & Nile Rodg...
# 47                                Cool for the Summer
# 48                        Boy With Luv (feat. Halsey)
# 49         Cheerleader - Felix Jaehn Remix Radio Edit
#
#                                       album                    artist  \
# 0                                      Blue                Jonas Blue
# 1                                         7              David Guetta
# 2                  One Kiss (with Dua Lipa)             Calvin Harris
# 3                                   Clarity                      Zedd
# 4                                    Encore                  DJ Snake
# 5                       Roses (feat. ROZES)          The Chainsmokers
# 6                                     Views                     Drake
# 7                                   Starboy                The Weeknd
# 8                                      DNCE                      DNCE
# 9                                      Blue                Jonas Blue
# 10  Nothing but the Beat (Ultimate Edition)              David Guetta
# 11                    How Deep Is Your Love             Calvin Harris
# 12                                Happy Now                      Zedd
# 13                                    Bloom               Troye Sivan
# 14                                   Closer          The Chainsmokers
# 15                                      LP1                Liam Payne
# 16                Beauty Behind The Madness                The Weeknd
# 17                         Flicker (Deluxe)               Niall Horan
# 18                   My Everything (Deluxe)             Ariana Grande
# 19                                     MKTO                      MKTO
# 20                                     HAIZ          Hailee Steinfeld
# 21                               The Middle                      Zedd
# 22                           Meet The Vamps                 The Vamps
# 23                   When The Sun Goes Down  Selena Gomez & The Scene
# 24                          Trust Fund Baby              Why Don't We
# 25                      Reflection (Deluxe)             Fifth Harmony
# 26   Pretty Girl (Cheat Codes X CADE Remix)          Maggie Lindemann
# 27                   My Everything (Deluxe)             Ariana Grande
# 28                 Speak Your Mind (Deluxe)                Anne-Marie
# 29                                     Demi               Demi Lovato
# 40          0.000004    0.0840    -5.589       0.1460  100.045
# 41          0.056400    0.2980    -4.194       0.0469  122.985
# 42          0.001380    0.1080    -4.485       0.0383  127.986
# 43          0.000003    0.3380    -6.439       0.0473  118.159
# 44          0.000157    0.0828    -3.004       0.0427  139.956
# 45          0.000000    0.1160    -3.145       0.0509  129.042
# 46          0.000002    0.0720    -9.404       0.0403  116.049
# 47          0.000105    0.1400    -5.639       0.0382  114.060
# 48          0.000000    0.1920    -4.757       0.0965  119.991
# 49          0.000012    0.1600    -6.237       0.0309  118.016
#
#     time_signature  valence  sad
# 0                4    0.566    0
# 1                4    0.421    0
# 2                4    0.592    0
# 3                4    0.176    0
# 4                4    0.224    0
# 5                4    0.343    0
# 6                4    0.370    0
# 7                4    0.486    0
# 8                4    0.896    0
# 9                4    0.548    0
# 10               4    0.301    0
# 11               4    0.336    0
# 12               3    0.458    0
# 13               4    0.712    0
# 14               4    0.661    0
# 15               4    0.546    0
# 16               4    0.583    0
# 17               4    0.848    0
# 18               4    0.625    0
# 19               4    0.755    0
# 20               4    0.324    0
# 21               4    0.437    0
# 22               4    0.583    0
# 23               4    0.744    0
# 24               4    0.593    0
# 25               4    0.594    0
# 26               4    0.733    0
# 27               4    0.284    0
# 28               4    0.603    0
# 29               4    0.851    0
# 30               4    0.706    0
# 31               4    0.507    0
# 32               4    0.573    0
# 33               4    0.484    0
# 34               4    0.736    0
# 35               4    0.952    0
# 36               4    0.862    0
# 37               4    0.618    0
# 38               4    0.885    0
# 39               4    0.272    0
# 40               4    0.755    0
# 41               4    0.379    0
# 42               4    0.600    0
# 43               4    0.505    0
# 44               4    0.715    0
# 45               4    0.438    0
# 46               4    0.863    0
# 47               4    0.336    0
# 48               4    0.798    0
# 49               4    0.603    0

# %% [markdown]
# <h3>Find the mean of all the music features for each playlist. Compare it.

# %%
pl3.df[['name','artist','energy','acousticness']].sort_values(by='energy')
# Out:
#                                          name           artist  energy  \
# 55                             Trying My Best     Anson Seabra  0.0587
# 94  Sinking Man - The Walking Dead Soundtrack  Various Artists  0.0646
# 59                               Slow It Down    The Lumineers  0.0657
# 92                        you were good to me    Jeremy Zucker  0.0848
# 18     Murder Song (5, 4, 3, 2, 1) - Acoustic           AURORA  0.0887
# ..                                        ...              ...     ...
# 21                      Love Is A Losing Game    Amy Winehouse  0.5610
# 20                              Before You Go    Lewis Capaldi  0.5750
# 60                                  Last Time         Johnning  0.5870
# 1                                  Breathe Me              Sia  0.6430
# 83                                The Funeral  Various Artists  0.7690
#
#     acousticness
# 55        0.9500
# 94        0.9050
# 59        0.9280
# 92        0.9130
# 18        0.9020
# ..           ...
# 21        0.3170
# 20        0.6040
# 60        0.1110
# 1         0.0364
# 83        0.0143
#
# [100 rows x 4 columns]

# %%
pl3.df['danceability'].mean()
# Out:
# 0.5136799999999997

# %%
x = pl3.df['acousticness'].values
plt.hist(x, bins = 10)
plt.show()

# %%
y = pl4.df['acousticness'].values
plt.hist(y, bins = 10)
plt.show()

# %% [markdown]
# Determine if song is happy or sad based on the playlist (1 or 0)
